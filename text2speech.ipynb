# %%
pip install gTTS

# %%
from gtts import gTTS 
from IPython.display import Audio

#this code is if you want to read a string of text written 
text = gTTS('hello this is a reading for away in bliss', lang="en", tld='com.ng') #adding localised accents via top level domain
text.save('1.wav')
sound_file = '1.wav'

Audio(sound_file, autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import os 

#this code is if you want to read text from a txt file 
def reading_from_file():
  file_to_read = input('please insert name of file:\n') + '.txt'
  f = open(file_to_read, 'r')
  file_text = f.read()
  f.close()

  audio_created = gTTS(text=file_text, lang="en", slow=False, tld='com.ng')
  audio_created.save("2.wav")

  os.system(f'start {"2.wav"}')

if __name__ == "__main__":
  reading_from_file()
# Out:
# please insert name of file:
# test

# %%
Audio('/content/2.wav', autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
